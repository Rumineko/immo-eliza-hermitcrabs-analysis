# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def parse_year(year):
    return pd.to_datetime(str(year), format='%Y')

# %%
immo_df = pd.read_csv('../data/raw/rawdata.csv', parse_dates=['Build Year'], date_format=parse_year)
immo_df.head()
# Out:
#          ID  Locality  Postal Code Build Year  Facades  Habitable Surface  \
# 0  11149965   Waremme         4300       1974      3.0              115.0
# 1  11149932  Wetteren         9230       2015      3.0              134.0
# 2  11150061   Ixelles         1050       1958      2.0              134.0
# 3  11153822   BERCHEM         2600       1968      2.0               90.0
# 4  11153121     Jette         1090       1965      2.0               80.0
#
#    Land Surface       Type    Subtype   Price  ... Has starting Price  \
# 0           NaN  APARTMENT  APARTMENT  220000  ...              False
# 1           NaN  APARTMENT     DUPLEX  339000  ...              False
# 2           NaN  APARTMENT  APARTMENT  495000  ...              False
# 3           NaN  APARTMENT  APARTMENT  175000  ...                NaN
# 4           NaN  APARTMENT  APARTMENT  289000  ...              False
#
#    Transaction Subtype  Heating Type  Is Holiday Property  \
# ...

# %%
immo_df.describe()
# Out:
#                  ID   Postal Code      Facades  Habitable Surface  \
# count  1.238800e+04  12388.000000  9271.000000       11996.000000
# mean   1.099838e+07   4302.356151     2.695610         134.342364
# std    3.796727e+05   3182.773362     0.835629         154.645256
# min    7.309243e+06   1000.000000     1.000000          12.000000
# 25%    1.101806e+07   1325.000000     2.000000          85.000000
# 50%    1.114095e+07   2960.000000     2.000000         107.000000
# 75%    1.115744e+07   7700.000000     3.000000         156.000000
# max    1.116304e+07   9990.000000     7.000000        7819.000000
#
#        Land Surface         Price  Bedroom Count  Bathroom Count  \
# count   4168.000000  1.238800e+04   12302.000000    10904.000000
# mean     817.716651  4.102685e+05       2.436758        1.300073
# std     2595.356915  3.105778e+05       1.361684        0.777219
# min        0.000000  3.000000e+04       0.000000        1.000000
# ...

# %%
immo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12388 entries, 0 to 12387
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     12388 non-null  int64
#  1   Locality               12388 non-null  object
#  2   Postal Code            12388 non-null  int64
#  3   Build Year             9230 non-null   object
#  4   Facades                9271 non-null   float64
#  5   Habitable Surface      11996 non-null  float64
#  6   Land Surface           4168 non-null   float64
#  7   Type                   12388 non-null  object
#  8   Subtype                12388 non-null  object
#  9   Price                  12388 non-null  int64
#  10  Sale Type              12388 non-null  object
#  11  Bedroom Count          12302 non-null  float64
#  12  Bathroom Count         10904 non-null  float64
#  13  Toilet Count           9676 non-null   float64
# ...

# %%
# Number of observations and columns
immo_df.shape
# Out:
# (12388, 43)

# %% [markdown]
# # We have 12388 observations, one target (Price) and 42 features

# %%
# Looking for missing values

immo_df.isna().any()
# Out:
# ID                       False
# Locality                 False
# Postal Code              False
# Build Year                True
# Facades                   True
# Habitable Surface         True
# Land Surface              True
# Type                     False
# Subtype                  False
# Price                    False
# Sale Type                False
# Bedroom Count             True
# Bathroom Count            True
# Toilet Count              True
# Room Count                True
# Kitchen                  False
# Kitchen Surface           True
# Kitchen Type              True
# Furnished                False
# Openfire                 False
# Fireplace Count           True
# Terrace                  False
# Terrace Surface           True
# Terrace Orientation       True
# Garden Exists            False
# Garden Surface            True
# Garden Orientation        True
# Swimming Pool             True
# State of Building         True
# Living Surface            True
# ...

# %%
# Proportion of missing values per column?

immo_df.isnull().mean()
# Out:
# ID                       0.000000
# Locality                 0.000000
# Postal Code              0.000000
# Build Year               0.254924
# Facades                  0.251614
# Habitable Surface        0.031644
# Land Surface             0.663545
# Type                     0.000000
# Subtype                  0.000000
# Price                    0.000000
# Sale Type                0.000000
# Bedroom Count            0.006942
# Bathroom Count           0.119793
# Toilet Count             0.218922
# Room Count               0.011866
# Kitchen                  0.000000
# Kitchen Surface          0.670810
# Kitchen Type             0.223119
# Furnished                0.000000
# Openfire                 0.000000
# Fireplace Count          0.757992
# Terrace                  0.000000
# Terrace Surface          0.345819
# Terrace Orientation      0.975299
# Garden Exists            0.000000
# Garden Surface           0.830723
# Garden Orientation       0.915644
# ...

# %%
# Printing all column names

immo_df.columns
# Out:
# Index(['ID', 'Locality', 'Postal Code', 'Build Year', 'Facades',
#        'Habitable Surface', 'Land Surface', 'Type', 'Subtype', 'Price',
#        'Sale Type', 'Bedroom Count', 'Bathroom Count', 'Toilet Count',
#        'Room Count', 'Kitchen', 'Kitchen Surface', 'Kitchen Type', 'Furnished',
#        'Openfire', 'Fireplace Count', 'Terrace', 'Terrace Surface',
#        'Terrace Orientation', 'Garden Exists', 'Garden Surface',
#        'Garden Orientation', 'Swimming Pool', 'State of Building',
#        'Living Surface', 'EPC', 'Consumption Per m2', 'Cadastral Income',
#        'Has starting Price', 'Transaction Subtype', 'Heating Type',
#        'Is Holiday Property', 'Gas Water Electricity', 'Sewer', 'Sea view',
#        'Parking count inside', 'Parking count outside', 'Parking box count'],
#       dtype='object')

# %%
# Selecting possible columns for analysis

columns_selected_names = ['Price', 'Postal Code', 'Build Year', 'Facades', 'Habitable Surface', 'Land Surface', 'Type', 'Subtype', 'Bedroom Count', 'Bathroom Count', 'Toilet Count', 'Room Count', 'Kitchen Surface', 'Furnished', 'Living Surface']

# %%
# Creating a new dataframe with the selected columns
immo_extracted = immo_df[columns_selected_names]
immo_extracted.head()
# Out:
#     Price  Postal Code Build Year  Facades  Habitable Surface  Land Surface  \
# 0  220000         4300       1974      3.0              115.0           NaN
# 1  339000         9230       2015      3.0              134.0           NaN
# 2  495000         1050       1958      2.0              134.0           NaN
# 3  175000         2600       1968      2.0               90.0           NaN
# 4  289000         1090       1965      2.0               80.0           NaN
#
#         Type    Subtype  Bedroom Count  Bathroom Count  Toilet Count  \
# 0  APARTMENT  APARTMENT            3.0             1.0           2.0
# 1  APARTMENT     DUPLEX            3.0             1.0           2.0
# 2  APARTMENT  APARTMENT            2.0             1.0           2.0
# 3  APARTMENT  APARTMENT            2.0             1.0           1.0
# 4  APARTMENT  APARTMENT            3.0             1.0           1.0
#
#    Room Count  Kitchen Surface  Furnished  Living Surface
# ...

# %%
immo_extracted.shape
# Out:
# (12388, 15)

# %%
immo_extracted.describe()
# Out:
#               Price   Postal Code      Facades  Habitable Surface  \
# count  1.238800e+04  12388.000000  9271.000000       11996.000000
# mean   4.102685e+05   4302.356151     2.695610         134.342364
# std    3.105778e+05   3182.773362     0.835629         154.645256
# min    3.000000e+04   1000.000000     1.000000          12.000000
# 25%    2.600000e+05   1325.000000     2.000000          85.000000
# 50%    3.342150e+05   2960.000000     2.000000         107.000000
# 75%    4.500000e+05   7700.000000     3.000000         156.000000
# max    7.650000e+06   9990.000000     7.000000        7819.000000
#
#        Land Surface  Bedroom Count  Bathroom Count  Toilet Count  \
# count   4168.000000   12302.000000    10904.000000   9676.000000
# mean     817.716651       2.436758        1.300073      1.564283
# std     2595.356915       1.361684        0.777219      0.931616
# min        0.000000       0.000000        1.000000      1.000000
# ...

# %%
immo_extracted.hist(figsize=(16, 20), bins=100)
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Postal Code'}>,
#         <Axes: title={'center': 'Facades'}>],
#        [<Axes: title={'center': 'Habitable Surface'}>,
#         <Axes: title={'center': 'Land Surface'}>,
#         <Axes: title={'center': 'Bedroom Count'}>],
#        [<Axes: title={'center': 'Bathroom Count'}>,
#         <Axes: title={'center': 'Toilet Count'}>,
#         <Axes: title={'center': 'Room Count'}>],
#        [<Axes: title={'center': 'Kitchen Surface'}>,
#         <Axes: title={'center': 'Living Surface'}>, <Axes: >]],
#       dtype=object)

# %%
correlation_matrix = immo_extracted[
    ['Price', 'Postal Code', 'Build Year', 'Facades', 'Habitable Surface', 'Land Surface', 'Bedroom Count',
     'Bathroom Count', 'Toilet Count', 'Room Count', 'Kitchen Surface', 'Living Surface']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
immo_extracted.Price.describe()
# Out:
# count    1.238800e+04
# mean     4.102685e+05
# std      3.105778e+05
# min      3.000000e+04
# 25%      2.600000e+05
# 50%      3.342150e+05
# 75%      4.500000e+05
# max      7.650000e+06
# Name: Price, dtype: float64

# %%
# Inspecting for outliers in Price
plt.figure(figsize=(10, 4)) 
plt.boxplot(immo_extracted['Price'])   
plt.title('Price')           
plt.ylabel('Values')       
plt.tight_layout()         
plt.show()

# %%
# Calculating the interquartile range (IQR)
Q1 = immo_extracted['Price'].quantile(0.25)
Q3 = immo_extracted['Price'].quantile(0.75)
IQR = Q3 - Q1

# the limits to detect outliers
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# Identify outliers
outliers = immo_extracted[(immo_extracted['Price'] < lower_limit) | (immo_extracted['Price'] > upper_limit )]

# Calculates the number of values inside the IQR and the number of outliers.
values_inside_IQR = immo_extracted[(immo_extracted['Price'] >= lower_limit) & (immo_extracted['Price'] <= upper_limit)].shape[0]
quantity_outliers = outliers.shape[0]

print(f"Price mean: {immo_extracted['Price'].mean()}")
print(f"Outliers Price mean: {outliers['Price'].mean()}")

print(f"Outliers Count: \n{outliers.count()}")
# Out:
# Price mean: 410268.4679528576
# Outliers Price mean: 1193198.4776422763
# Outliers Count:
# Price                984
# Postal Code          984
# Build Year           785
# Facades              808
# Habitable Surface    966
# Land Surface         460
# Type                 984
# Subtype              984
# Bedroom Count        982
# Bathroom Count       928
# Toilet Count         833
# Room Count           976
# Kitchen Surface      385
# Furnished            984
# Living Surface       546
# dtype: int64

# %%
columns_selected_names = ['Price', 'Subtype']

for property_type in immo_extracted['Subtype'].unique():
    plt.figure(figsize=(8, 6))  
    data_subset = immo_extracted[immo_extracted['Subtype'] == property_type]
    plt.boxplot(data_subset['Price']) 
    plt.title(property_type) 
    plt.ylabel('Price') 
    plt.xticks([1], [property_type])
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
sns.boxplot(data=immo_extracted, x='Postal Code', y='Price')
# Out:
# <Axes: xlabel='Postal Code', ylabel='Price'>

# %%
# Sorting zip codes by median price
sorted_postal_codes = immo_extracted.groupby('Postal Code')['Price'].median().sort_values(ascending=False).index

# Limit the number of displayed zip codes
n_top_postal_codes = 30
top_postal_codes = sorted_postal_codes[:n_top_postal_codes]

# Filter the DataFrame to include only the selected zip codes
immo_filtered = immo_extracted[immo_extracted['Postal Code'].isin(top_postal_codes)]

# Configure the size of the figure
plt.figure(figsize=(12, 6))

# Create the box plot
sns.boxplot(data=immo_filtered, x='Postal Code', y='Price')

# Rotate x-axis ticks to improve readability
plt.xticks(rotation=45)

# Add title and axis labels
plt.title('Price by Zip Code Boxplot')
plt.xlabel('Zip Code')
plt.ylabel('Price')

# Show the graph
plt.tight_layout()
plt.show()

# %%
immo_extracted['Type'].unique()
# Out:
# array(['APARTMENT', 'HOUSE', 'OFFICE', 'COMMERCIAL', 'LAND', 'GARAGE'],
#       dtype=object)

# %%
immo_houses = immo_extracted[immo_extracted['Type'] == 'HOUSE']
immo_houses
# Out:
#         Price  Postal Code Build Year  Facades  Habitable Surface  \
# 113    378500         9800       2024      2.0              123.0
# 114    378500         9800       2024      2.0              123.0
# 115    378500         9800       2024      2.0              123.0
# 116    381000         9800       2024      2.0              123.0
# 117    399500         9800       2024      3.0              123.0
# ...       ...          ...        ...      ...                ...
# 12381  245000         3530       1958      3.0              110.0
# 12382  219000         4000       1957      2.0              148.0
# 12383  499000         3690       1991      4.0              206.0
# 12384  325000         8470       1958      2.0              270.0
# 12386  899000         3071       1991      4.0              390.0
#
#        Land Surface   Type Subtype  Bedroom Count  Bathroom Count  \
# 113           175.0  HOUSE   HOUSE            3.0             1.0
# ...

# %%
for type in immo_extracted['Type'].unique():
    slice_df = immo_extracted[immo_extracted['Type'] == type]
    
    correlation_matrix = slice_df[
        ['Price', 'Postal Code', 'Build Year', 'Facades', 'Habitable Surface', 'Land Surface', 'Bedroom Count',
         'Bathroom Count', 'Toilet Count', 'Room Count', 'Kitchen Surface', 'Living Surface']].corr()
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
    plt.title(f"Correlation Matrix - {type}")
    plt.show()
# Out:
# /home/karel/anaconda3/envs/becode/lib/python3.11/site-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /home/karel/anaconda3/envs/becode/lib/python3.11/site-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
